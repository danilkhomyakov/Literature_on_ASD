# %% [markdown]
# <a href="https://colab.research.google.com/github/danilkhomyakov/Literature_on_ASD/blob/main/faster_whisper_youtube_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube/Google Drive Videos Translation/Transcription with Faster Whisper**
#
# [faster-whisper](https://github.com/guillaumekln/faster-whisper) is a reimplementation of OpenAI's Whisper model using CTranslate2, which is a fast inference engine for Transformer models.
#
# This implementation is up to 4 times faster than openai/whisper for the same accuracy while using less memory. The efficiency can be further improved with 8-bit quantization on both CPU and GPU.
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription or translation of a  video file (from Youtube/Google Drive) using Faster Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the output and video audio in your Google Drive.
#
# ## **How to use**
# 1. Read and understand the notebook. You should at the very least modify the **video selection section** to choose the video you wish to translate/transcribe
# 2. Click Runtime -> Run all and wait for the notebook to do its magic, alternatively you may run the cells one by one and skip the Google Drive portion if you do not intend to use it
# 3. A download prompt should appear once subtitles is ready, or check the 'Files' tab on the left for the output

# %%
#@markdown # **[Optional]** Access data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
from pathlib import Path

drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Faster Whisper" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-8f34a7fc-21cc-5234-b35d-97b1fd2770c7)
# Thu Sep  4 15:29:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Faster Whisper.

#@markdown ---

! pip install faster-whisper
! pip install yt-dlp

import os
import sys
import warnings
from faster_whisper import WhisperModel
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo
import requests
from urllib.parse import urlsplit
from google.colab import files
from pathlib import Path

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)

# !sudo apt-get update
# !sudo apt install nvidia-cuda-toolkit
# Out:
# Collecting faster-whisper
#   Downloading faster_whisper-1.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.34.4)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.21.4)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (1.1.8)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Downloading faster_whisper-1.2.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.8 MB/s eta 0:00:00
# Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 35.8 MB/s eta 0:00:00
# Downloading ctranslate2-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 14.0 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 82.4 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.7 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, ctranslate2, av, coloredlogs, onnxruntime, faster-whisper
# Successfully installed av-15.1.0 coloredlogs-15.0.1 ctranslate2-4.6.0 faster-whisper-1.2.0 humanfriendly-10.0 onnxruntime-1.22.1
# Collecting yt-dlp
#   Downloading yt_dlp-2025.8.27-py3-none-any.whl.metadata (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 14.2 MB/s eta 0:00:00
# Downloading yt_dlp-2025.8.27-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.4 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.8.27
# Using device: cuda:0
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,961 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,242 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,272 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,580 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,374 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,623 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,310 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,791 kB]
# Fetched 29.5 MB in 4s (6,738 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
#   libcudart11.0 libcufft10 libcufftw10 libcuinj64-11.5 libcupti-dev
#   libcupti-doc libcupti11.5 libcurand10 libcusolver11 libcusolvermg11
#   libcusparse11 libdebuginfod-common libdebuginfod1 libegl-dev libgail-common
#   libgail18 libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglvnd-core-dev
#   libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libipt2
#   libnppc11 libnppial11 libnppicc11 libnppidei11 libnppif11 libnppig11
#   libnppim11 libnppist11 libnppisu11 libnppitc11 libnpps11 libnvblas11
#   libnvidia-compute-495 libnvidia-compute-510 libnvidia-compute-535
#   libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5 libnvrtc11.2
#   libnvtoolsext1 libnvvm4 libopengl-dev librsvg2-common
#   libsource-highlight-common libsource-highlight4v5 libthrust-dev libvdpau-dev
#   libxtst6 libxxf86dga1 node-html5shiv nvidia-cuda-dev nvidia-cuda-gdb
#   nvidia-cuda-toolkit-doc nvidia-profiler nvidia-visual-profiler openjdk-8-jre
#   openjdk-8-jre-headless x11-utils
# Suggested packages:
#   gvfs libvdpau-doc nodejs libnss-mdns fonts-nanum fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei fonts-wqy-zenhei fonts-indic
#   mesa-utils
# Recommended packages:
#   libnvcuvid1 nsight-compute nsight-systems
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
#   libcudart11.0 libcufft10 libcufftw10 libcuinj64-11.5 libcupti-dev
#   libcupti-doc libcupti11.5 libcurand10 libcusolver11 libcusolvermg11
#   libcusparse11 libdebuginfod-common libdebuginfod1 libegl-dev libgail-common
#   libgail18 libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglvnd-core-dev
#   libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libipt2
#   libnppc11 libnppial11 libnppicc11 libnppidei11 libnppif11 libnppig11
#   libnppim11 libnppist11 libnppisu11 libnppitc11 libnpps11 libnvblas11
#   libnvidia-compute-495 libnvidia-compute-510 libnvidia-compute-535
#   libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5 libnvrtc11.2
#   libnvtoolsext1 libnvvm4 libopengl-dev librsvg2-common
#   libsource-highlight-common libsource-highlight4v5 libthrust-dev libvdpau-dev
#   libxtst6 libxxf86dga1 node-html5shiv nvidia-cuda-dev nvidia-cuda-gdb
#   nvidia-cuda-toolkit nvidia-cuda-toolkit-doc nvidia-profiler
#   nvidia-visual-profiler openjdk-8-jre openjdk-8-jre-headless x11-utils
# 0 upgraded, 75 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,540 MB of archives.
# After this operation, 4,233 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdebuginfod-common all 0.186-1ubuntu0.1 [7,996 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-535 535.261.03-0ubuntu1 [36.9 MB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti11.5 amd64 11.5.114~11.5.1-1ubuntu1 [7,696 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libaccinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [845 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcub-dev all 1.15.0-3 [217 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublaslt11 amd64 11.7.4.6~11.5.1-1ubuntu1 [148 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [78.2 MB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcudart11.0 amd64 11.5.117~11.5.1-1ubuntu1 [178 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufft10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [70.4 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufftw10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [211 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-510 amd64 525.147.05-0ubuntu2.22.04.1 [7,310 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-495 amd64 510.108.03-0ubuntu0.22.04.1 [7,378 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcuinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [1,004 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcurand10 amd64 11.1.1+~10.2.7.107~11.5.1-1ubuntu1 [41.8 MB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolver11 amd64 11.3.2.107~11.5.1-1ubuntu1 [31.3 MB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolvermg11 amd64 11.3.2.107~11.5.1-1ubuntu1 [17.8 MB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusparse11 amd64 11.7.0.107~11.5.1-1ubuntu1 [96.2 MB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdebuginfod1 amd64 0.186-1ubuntu0.1 [12.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libipt2 amd64 2.0.5-1 [46.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [430 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppial11 amd64 11.5.1.107~11.5.1-1ubuntu1 [5,234 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppicc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,373 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppidei11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,587 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppif11 amd64 11.5.1.107~11.5.1-1ubuntu1 [33.8 MB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppig11 amd64 11.5.1.107~11.5.1-1ubuntu1 [14.5 MB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppim11 amd64 11.5.1.107~11.5.1-1ubuntu1 [3,037 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppist11 amd64 11.5.1.107~11.5.1-1ubuntu1 [13.7 MB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppisu11 amd64 11.5.1.107~11.5.1-1ubuntu1 [177 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppitc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [1,292 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnpps11 amd64 11.5.1.107~11.5.1-1ubuntu1 [7,116 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvblas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [191 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvidia-ml-dev amd64 11.5.50~11.5.1-1ubuntu1 [69.1 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvjpeg11 amd64 11.5.4.107~11.5.1-1ubuntu1 [1,858 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc-builtins11.5 amd64 11.5.119~11.5.1-1ubuntu1 [116 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc11.2 amd64 11.5.119~11.5.1-1ubuntu1 [15.7 MB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvvm4 amd64 11.5.119~11.5.1-1ubuntu1 [8,675 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight-common all 3.1.9-4.1build2 [64.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight4v5 amd64 3.1.9-4.1build2 [207 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau-dev amd64 1.4-3build2 [38.7 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 node-html5shiv all 3.7.3+dfsg-4 [13.6 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit-doc all 11.5.1-1ubuntu1 [6,263 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre-headless amd64 8u462-ga~us1-0ubuntu2~22.04.2 [30.8 MB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre amd64 8u462-ga~us1-0ubuntu2~22.04.2 [75.5 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libbabeltrace1 amd64 1.5.8-2build1 [160 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-dev amd64 11.5.114~11.5.1-1ubuntu1 [7,915 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-doc all 11.5.114~11.5.1-1ubuntu1 [2,373 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvtoolsext1 amd64 11.5.114~11.5.1-1ubuntu1 [28.8 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libthrust-dev all 1.15.0-1 [423 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-dev amd64 11.5.1-1ubuntu1 [667 MB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-gdb amd64 11.5.114~11.5.1-1ubuntu1 [3,404 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-profiler amd64 11.5.114~11.5.1-1ubuntu1 [1,732 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit amd64 11.5.1-1ubuntu1 [62.8 MB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-visual-profiler amd64 11.5.114~11.5.1-1ubuntu1 [108 MB]
# Fetched 1,540 MB in 1min 30s (17.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 75.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libdebuginfod-common.
# (Reading database ... 126374 files and directories currently installed.)
# Preparing to unpack .../00-libdebuginfod-common_0.186-1ubuntu0.1_all.deb ...
# Unpacking libdebuginfod-common (0.186-1ubuntu0.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../01-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../02-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libcupti11.5:amd64.
# Preparing to unpack .../03-libcupti11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libaccinj64-11.5:amd64.
# Preparing to unpack .../04-libaccinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../05-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../06-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../07-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../08-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../09-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libcub-dev.
# Preparing to unpack .../10-libcub-dev_1.15.0-3_all.deb ...
# Unpacking libcub-dev (1.15.0-3) ...
# Selecting previously unselected package libcublaslt11:amd64.
# Preparing to unpack .../11-libcublaslt11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcublas11:amd64.
# Preparing to unpack .../12-libcublas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcudart11.0:amd64.
# Preparing to unpack .../13-libcudart11.0_11.5.117~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufft10:amd64.
# Preparing to unpack .../14-libcufft10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufftw10:amd64.
# Preparing to unpack .../15-libcufftw10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-535:amd64.
# Preparing to unpack .../16-libnvidia-compute-535_535.261.03-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-535:amd64 (535.261.03-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-510:amd64.
# Preparing to unpack .../17-libnvidia-compute-510_525.147.05-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Selecting previously unselected package libnvidia-compute-495:amd64.
# Preparing to unpack .../18-libnvidia-compute-495_510.108.03-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcuinj64-11.5:amd64.
# Preparing to unpack .../19-libcuinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcurand10:amd64.
# Preparing to unpack .../20-libcurand10_11.1.1+~10.2.7.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolver11:amd64.
# Preparing to unpack .../21-libcusolver11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolvermg11:amd64.
# Preparing to unpack .../22-libcusolvermg11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusparse11:amd64.
# Preparing to unpack .../23-libcusparse11_11.7.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libdebuginfod1:amd64.
# Preparing to unpack .../24-libdebuginfod1_0.186-1ubuntu0.1_amd64.deb ...
# Unpacking libdebuginfod1:amd64 (0.186-1ubuntu0.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../25-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../26-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../27-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../28-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../29-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../30-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../31-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../32-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../33-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../34-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libipt2.
# Preparing to unpack .../35-libipt2_2.0.5-1_amd64.deb ...
# Unpacking libipt2 (2.0.5-1) ...
# Selecting previously unselected package libnppc11:amd64.
# Preparing to unpack .../36-libnppc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppial11:amd64.
# Preparing to unpack .../37-libnppial11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppicc11:amd64.
# Preparing to unpack .../38-libnppicc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppidei11:amd64.
# Preparing to unpack .../39-libnppidei11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppif11:amd64.
# Preparing to unpack .../40-libnppif11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppig11:amd64.
# Preparing to unpack .../41-libnppig11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppim11:amd64.
# Preparing to unpack .../42-libnppim11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppist11:amd64.
# Preparing to unpack .../43-libnppist11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppisu11:amd64.
# Preparing to unpack .../44-libnppisu11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppitc11:amd64.
# Preparing to unpack .../45-libnppitc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnpps11:amd64.
# Preparing to unpack .../46-libnpps11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvblas11:amd64.
# Preparing to unpack .../47-libnvblas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-ml-dev:amd64.
# Preparing to unpack .../48-libnvidia-ml-dev_11.5.50~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvjpeg11:amd64.
# Preparing to unpack .../49-libnvjpeg11_11.5.4.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc-builtins11.5:amd64.
# Preparing to unpack .../50-libnvrtc-builtins11.5_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc11.2:amd64.
# Preparing to unpack .../51-libnvrtc11.2_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvvm4:amd64.
# Preparing to unpack .../52-libnvvm4_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../53-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../54-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libsource-highlight-common.
# Preparing to unpack .../55-libsource-highlight-common_3.1.9-4.1build2_all.deb ...
# Unpacking libsource-highlight-common (3.1.9-4.1build2) ...
# Selecting previously unselected package libsource-highlight4v5.
# Preparing to unpack .../56-libsource-highlight4v5_3.1.9-4.1build2_amd64.deb ...
# Unpacking libsource-highlight4v5 (3.1.9-4.1build2) ...
# Selecting previously unselected package libvdpau-dev:amd64.
# Preparing to unpack .../57-libvdpau-dev_1.4-3build2_amd64.deb ...
# Unpacking libvdpau-dev:amd64 (1.4-3build2) ...
# Selecting previously unselected package node-html5shiv.
# Preparing to unpack .../58-node-html5shiv_3.7.3+dfsg-4_all.deb ...
# Unpacking node-html5shiv (3.7.3+dfsg-4) ...
# Selecting previously unselected package nvidia-cuda-toolkit-doc.
# Preparing to unpack .../59-nvidia-cuda-toolkit-doc_11.5.1-1ubuntu1_all.deb ...
# Unpacking nvidia-cuda-toolkit-doc (11.5.1-1ubuntu1) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../60-openjdk-8-jre-headless_8u462-ga~us1-0ubuntu2~22.04.2_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u462-ga~us1-0ubuntu2~22.04.2) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../61-openjdk-8-jre_8u462-ga~us1-0ubuntu2~22.04.2_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u462-ga~us1-0ubuntu2~22.04.2) ...
# Selecting previously unselected package libbabeltrace1:amd64.
# Preparing to unpack .../62-libbabeltrace1_1.5.8-2build1_amd64.deb ...
# Unpacking libbabeltrace1:amd64 (1.5.8-2build1) ...
# Selecting previously unselected package libcupti-dev:amd64.
# Preparing to unpack .../63-libcupti-dev_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcupti-doc.
# Preparing to unpack .../64-libcupti-doc_11.5.114~11.5.1-1ubuntu1_all.deb ...
# Unpacking libcupti-doc (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../65-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../66-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../67-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libnvtoolsext1:amd64.
# Preparing to unpack .../68-libnvtoolsext1_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libthrust-dev.
# Preparing to unpack .../69-libthrust-dev_1.15.0-1_all.deb ...
# Unpacking libthrust-dev (1.15.0-1) ...
# Selecting previously unselected package nvidia-cuda-dev:amd64.
# Preparing to unpack .../70-nvidia-cuda-dev_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-gdb.
# Preparing to unpack .../71-nvidia-cuda-gdb_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-gdb (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-profiler.
# Preparing to unpack .../72-nvidia-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-toolkit.
# Preparing to unpack .../73-nvidia-cuda-toolkit_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-visual-profiler.
# Preparing to unpack .../74-nvidia-visual-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-visual-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libdebuginfod-common (0.186-1ubuntu0.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/profile.d/debuginfod.sh with new version
#
# Creating config file /etc/profile.d/debuginfod.csh with new version
# Setting up libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libdebuginfod1:amd64 (0.186-1ubuntu0.1) ...
# Setting up node-html5shiv (3.7.3+dfsg-4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libcupti-doc (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libsource-highlight-common (3.1.9-4.1build2) ...
# Setting up libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Setting up libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Setting up libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u462-ga~us1-0ubuntu2~22.04.2) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up libipt2 (2.0.5-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libbabeltrace1:amd64 (1.5.8-2build1) ...
# Setting up libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-535:amd64 (535.261.03-0ubuntu1) ...
# Setting up libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libvdpau-dev:amd64 (1.4-3build2) ...
# Setting up libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libcub-dev (1.15.0-3) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up nvidia-cuda-toolkit-doc (11.5.1-1ubuntu1) ...
# Setting up libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Setting up libsource-highlight4v5 (3.1.9-4.1build2) ...
# Setting up libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libthrust-dev (1.15.0-1) ...
# Setting up libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-gdb (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Setting up libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up openjdk-8-jre:amd64 (8u462-ga~us1-0ubuntu2~22.04.2) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up nvidia-visual-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
#@markdown # **Model selection** 🧠

#@markdown There are several models to choose from, with varying performance and speed. large-v2 is recommended for most cases:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~0.8 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1.0 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~1.4 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~2.7 GB     |      ~2x       |
#@markdown | large-v1  |   1550 M   |        N/A         |      `large-v1`       |    ~4.3 GB     |       1x       |
#@markdown | large-v2  |   1550 M   |        N/A         |      `large-v2`       |    ~4.3 GB     |       1x       |

#@markdown ---
model_size = 'medium' #@param ['tiny', 'tiny.en', 'base', 'base.en', 'small', 'small.en', 'medium', 'medium.en', 'large-v1', 'large-v2']
device_type = "cuda" #@param {type:"string"} ['cuda', 'cpu']
compute_type = "float16" #@param {type:"string"} ['float16', 'int8_float16', 'int8']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

model = WhisperModel(model_size, device=device_type, compute_type=compute_type)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# vocabulary.txt: 0.00B [00:00, ?B/s]
# model.bin:   0%|          | 0.00/1.53G [00:00<?, ?B/s]

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video **OR** Google drive video path of the video you want to translate/transcribe, and run the cell. Make sure the correct Type is chosen! This may take awhile depending on video file size.

Type = "Google Drive" #@param ['Youtube video or playlist', 'Google Drive', 'Direct download']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=9ez8lm9I26Y" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/Faster Whisper/1608.mp3" #@param {type:"string"}
#@markdown ---
#@markdown #### **Direct Download**
ddl_url = "https://www.example.com/video.mkv" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for processing.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        print(f"{video_path_local} appended to list for processing")
        display(Markdown(f"**{str(video_path)} selected for processing.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

elif Type == "Direct download":
    print(f"⚠️ Please ensure this is a direct download link and is of a valid format")
    print(f"Attempting to download: {ddl_url}\n")
    # !wget {ddl_url} -O ddl_video.mp4
    # video_path_local_list.append("/content/ddl_video.mp4")

    response = requests.get(ddl_url)

    if response.status_code == 200:
        # Extract the filename from the URL
        filename = urlsplit(ddl_url).path.split("/")[-1]

        # Create the full path for the destination file in the current working directory
        destination_path = os.path.join(os.getcwd(), filename)

        # Save the file
        with open(destination_path, 'wb') as file:
            file.write(response.content)

        print(f"File downloaded successfully: {destination_path}")

        video_path_local = Path(".").resolve() / (filename)

        # print(f"Path local: {video_path_local}") # /content/video.mkv

        video_path_local_list.append(video_path_local)
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    valid_suffixes = [".mp4", ".mkv", ".mov", ".avi", ".wmv", ".flv", ".webm", ".3gp", ".mpeg"]

    print(f"Processing video file {video_path_local} with ffmpeg..")

    if video_path_local.suffix in valid_suffixes:
        input_suffix = video_path_local.suffix
        video_path_local = video_path_local.with_suffix(".wav")
        result = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(input_suffix)), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# /content/1608.mp3 appended to list for processing
# **/content/drive/My Drive/Colab Notebooks/Faster Whisper/1608.mp3 selected for processing.**
# Processing video file /content/1608.mp3 with ffmpeg..

# %%
def seconds_to_time_format(s):
    # Convert seconds to hours, minutes, seconds, and milliseconds
    hours = s // 3600
    s %= 3600
    minutes = s // 60
    s %= 60
    seconds = s // 1
    milliseconds = round((s % 1) * 1000)
    # Return the formatted string
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d},{int(milliseconds):03d}"

#@markdown # **Run the model** 🚀
#@markdown Run this cell to execute the transcription/translation of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown #### Language
language = "ru"  #@param ["ru", "auto", "en", "zh", "ja", "fr", "de"] {allow-input: true}
#@markdown #### initial prompt (change to transcribe if you prefer transcribing only)
initial_prompt = ""  #@param {type:"string"}
#@markdown ---
#@markdown #### Word-level timestamps
word_level_timestamps = False  #@param {type:"boolean"}
#@markdown ---
#@markdown #### VAD filter
vad_filter = True  #@param {type:"boolean"}
vad_filter_min_silence_duration_ms = 200  #@param {type:"integer"}
#@markdown ---
#@markdown #### Output (Default is srt, txt if `text_only` be checked )
text_only = True  #@param {type:"boolean"}

#@markdown ---
#@markdown ### **Paragraph builder (TXT-only)** ✂️
#@markdown Настройки работают **только если `text_only=True`**. Помогают собирать читаемые абзацы:
#@markdown * **gap_threshold_s** — *секунды паузы* между сегментами, после которых можно начать **новый абзац**. Меньше → чаще делит по коротким паузам.
#@markdown * **min_para_len** — минимальная длина абзаца (символы), чтобы не рвать слишком короткие куски.
#@markdown * **max_para_len** — «мягкий потолок» длины абзаца (символы): если достигли и есть конец предложения — разрываем.
#@markdown * **limit_by_sentences** — ограничивать размер абзаца по **числу предложений**.
#@markdown * **max_sentences_per_para** — максимум предложений в одном абзаце (учитываются `. ! ? …`). Полезно, если лекции выходят длинными монологами.
gap_threshold_s = 1.0  #@param {type:"number"}
min_para_len = 70      #@param {type:"integer"}
max_para_len = 600     #@param {type:"integer"}
limit_by_sentences = True  #@param {type:"boolean"}
max_sentences_per_para = 4  #@param {type:"integer"}

# --- Транскрипция ---
_language_for_model = None if language == "auto" else language

segments, info = model.transcribe(
    str(video_path_local),
    task="transcribe",
    beam_size=5,
    language=_language_for_model,
    initial_prompt=initial_prompt or None,
    word_timestamps=word_level_timestamps,
    vad_filter=vad_filter,
    vad_parameters=dict(min_silence_duration_ms=vad_filter_min_silence_duration_ms),
    # Помогаем пунктуации, не меняя остальную логику
    condition_on_previous_text=True,
    prepend_punctuations="'\"“¿([{-",
    append_punctuations="'.。,，!！?？:：”)]}、",
)

display(Markdown(f"Detected language '{info.language}' with probability {info.language_probability}"))

ext_name = '.txt' if text_only else ".srt"
output_file_name = video_path_local.stem + ext_name
sentence_idx = 1

if word_level_timestamps:
    # Ветка покадровых таймкодов — как у вас
    with open(output_file_name, 'w', encoding='utf-8') as f:
        for segment in segments:
            for word in segment.words:
                ts_start = seconds_to_time_format(word.start)
                ts_end = seconds_to_time_format(word.end)
                print(f"[{ts_start} --> {ts_end}] {word.word}")
                if not text_only:
                    f.write(f"{sentence_idx}\n")
                    f.write(f"{ts_start} --> {ts_end}\n")
                    f.write(f"{word.word}\n\n")
                else:
                    f.write(f"{word.word}\n")
                sentence_idx += 1

elif not text_only:
    # Классический SRT по сегментам — как у вас
    with open(output_file_name, 'w', encoding='utf-8') as f:
        for segment in segments:
            ts_start = seconds_to_time_format(segment.start)
            ts_end = seconds_to_time_format(segment.end)
            print(f"[{ts_start} --> {ts_end}] {segment.text}")
            f.write(f"{sentence_idx}\n")
            f.write(f"{ts_start} --> {ts_end}\n")
            f.write(f"{segment.text.strip()}\n\n")
            sentence_idx += 1

else:
    # text_only=True → собираем АБЗАЦЫ
    end_marks = ('.', '!', '?', '…')

    paras = []
    buf = ""
    prev_end = None
    sentences_in_buf = 0

    with open(output_file_name, 'w', encoding='utf-8') as f:
        for segment in segments:
            ts_start = seconds_to_time_format(segment.start)
            ts_end = seconds_to_time_format(segment.end)
            print(f"[{ts_start} --> {ts_end}] {segment.text}")

            text = segment.text.strip()
            if not text:
                prev_end = segment.end
                continue

            # Пауза между сегментами
            gap = 999 if prev_end is None else max(0.0, segment.start - prev_end)

            # Решаем, делить ли абзац перед добавлением нового текста
            need_break = False
            if gap > gap_threshold_s and len(buf) >= min_para_len:
                need_break = True
            elif buf.endswith(end_marks) and len(buf) >= min_para_len:
                need_break = True
            elif len(buf) >= max_para_len and buf.endswith(end_marks):
                need_break = True
            elif limit_by_sentences and sentences_in_buf >= max_sentences_per_para and buf.endswith(end_marks):
                need_break = True

            if need_break and buf.strip():
                # Сброс текущего абзаца
                line = ' '.join(buf.strip().split())
                paras.append(line)
                buf = ""
                sentences_in_buf = 0

            # Добавляем текущий сегмент в буфер
            if buf and not buf.endswith((' ', '-', '—')):
                buf += ' '
            buf += text
            # Прибавляем кол-во завершённых предложений в этом сегменте
            sentences_in_buf += sum(ch in end_marks for ch in text)

            prev_end = segment.end

        # Финальный сброс
        if buf.strip():
            line = ' '.join(buf.strip().split())
            paras.append(line)

        f.write('\n\n'.join(paras))

try:
    files.download(output_file_name)
    shutil.copy(
        video_path_local.parent / output_file_name,
        drive_whisper_path / output_file_name
    )
    display(Markdown(f"**Output file created: {drive_whisper_path / output_file_name}**"))
except Exception:
    display(Markdown(f"**Output file created: {video_path_local.parent / output_file_name}**"))
# Out:
# Detected language 'ru' with probability 1
# [00:00:00,000 --> 00:00:05,800]  Итак, здравствуйте! Очередное воскресенье, хотя если все сложилось правильно, то возможно с более простеньким монтажом,
# [00:00:05,800 --> 00:00:09,440]  но эти новости выходят в субботу, потому что прошел разговор Трампа с Путиным,
# [00:00:09,440 --> 00:00:13,680]  а это самое главное событие, мои предсказания по которому сбылись на 100%,
# [00:00:13,680 --> 00:00:17,160]  несмотря на то, что я иногда ошибаюсь, иногда я все-таки оказываюсь прав.
# [00:00:17,160 --> 00:00:21,680]  Но восхваление меня во второй половине ролика, а сейчас главные новости прошедшей недели,
# [00:00:21,680 --> 00:00:26,000]  потому что, несмотря на то, что внимание всех было приковано в этот раз к Аляске,
# [00:00:26,000 --> 00:00:27,720]  все-таки происходили всякие события.
# [00:00:27,720 --> 00:00:32,300]  Трагедия в Юрмале.
# [00:00:32,300 --> 00:00:37,660]  Печальное известие пришло из Юрмала. Вчера в автомобильной катастрофе погиб один из кумиров
# [00:00:37,660 --> 00:00:43,180]  советской молодежи, известный в мире рок-исполнитель Виктор Цой. Трагедия произошла,
# [00:00:43,180 --> 00:00:48,260]  когда певец возвращался на автомобиле с рыбалки в Юрмале, где он проводил свой отпуск. По словам
# [00:00:48,260 --> 00:00:52,740]  сотрудников госавтоинспекции, Цой заснул за рулем и врезался в автобус.
# [00:00:52,740 --> 00:00:57,340]  И, как вы поняли, речь не про Галкина, которого в Юрмале недавно переехали на велике,
# [00:00:57,340 --> 00:01:02,260]  впрочем, как и моего редактора Дениса. Пидарасы, которые ездят на полной скорости по городу, вы
# [00:01:02,260 --> 00:01:09,060]  в случае с трагедией в Юрмале, речь у нас идет про Цоя, потому что сегодня своеобразный юбилей.
# [00:01:09,060 --> 00:01:14,340]  35 лет со дня его гибели. Пидарасы, которые на автобусах гоняют, избивают, на чем он там,
# [00:01:14,340 --> 00:01:19,260]  на жигулях ехал, в общем, вы пидарасы. При этом забавно, что творчество Галкина с породиями
# [00:01:19,260 --> 00:01:25,260]  на Ленина, Сталина и Брежнева пережило Цоя. И так все вместе в один голос. Господи, верни Цоя,
# [00:01:25,300 --> 00:01:31,740]  забери Галкина. Господи, верни Цоя, забери Галкина. Господи, верни Цоя, забери Галкина. Но мы же с вами
# [00:01:31,740 --> 00:01:36,460]  прекрасно понимаем, что все эти возгласы останутся без Божьего ответа, как будто бы
# [00:01:36,460 --> 00:01:42,300]  мольбы Иисуса, воскревшего перед Инквизитором в братьях Карамазовых, потому что Бог не хочет
# [00:01:42,300 --> 00:01:46,780]  страдать за наши грехи, поэтому он забрал Цоя, а не Галкина. Галкин будет жить очень долго,
# [00:01:46,780 --> 00:01:51,900]  Бог не хочет видеть его около себя. Такой нахуй Галкина. Ведь, естественно, Цой на небесах в качестве
# [00:01:51,900 --> 00:01:56,460]  артиста намного-намного предпочтительнее. А нам с вами остается довольствоваться лишь тем,
# [00:01:56,460 --> 00:02:01,580]  что Цой после себя оставил простые и хорошие песни. Конечно, далеко не все из них шедевр,
# [00:02:01,580 --> 00:02:06,540]  но многие западают в душу и являются частью репертуара абсолютно любого начинающего гитариста.
# [00:02:06,540 --> 00:02:11,900]  Царство небесное, Виктор. В детстве постоянно путал Виктора Цоя и Юрия Хоя. Типа на три буквы,
# [00:02:11,900 --> 00:02:16,740]  блин, кто из них Юрий, а кто Виктор. А еще знаешь, что понял? На улице Железнодорожной в Красногорске,
# [00:02:16,740 --> 00:02:21,780]  в доме 33, в котором я тогда жил, меня постоянно заебывало, типа я выходил и все стены были
# [00:02:21,780 --> 00:02:26,380]  расписаны какой-то хуйней, типа кино или Герой Асфальта. Я думал, блядь, что это за фильм,
# [00:02:26,380 --> 00:02:31,700]  что он так в душу запал. Но мне там было лет 7-8. Герой Асфальта. А это альбом, блядь, Ари. Я до
# [00:02:31,700 --> 00:02:37,020]  сих пор не понимаю, что за долбоебы предпочитали писать это везде. Герой Асфальта. Ну и хули-то дальше
# [00:02:37,020 --> 00:02:41,700]  это, блядь. Они, знаешь, они писали плейлисты, блядь, этого альбома из шести песен там, блядь. Кровь,
# [00:02:41,700 --> 00:02:46,700]  что-то там, Герой Асфальта, еще какая-то хуйня. Ну были же долбоебы, а? Они выросли и пересели на БМВ.
# [00:02:46,700 --> 00:02:54,260]  Прокурор запросил для Ильи Варламова срок в 8 лет и 99 миллионов рублей штрафа, потому что ему
# [00:02:54,260 --> 00:02:59,380]  предъявляют обвинение в уклонении от обязанности иностранного агента, а также в публичном
# [00:02:59,380 --> 00:03:04,500]  распространении под видом достоверных сообщений заведомо ложной информации об использовании в
# [00:03:04,500 --> 00:03:10,460]  СРФ по мотивам политической ненависти. Да, примерно так звучит обвинение. Очень, очень оно громоздкое.
# [00:03:10,460 --> 00:03:16,180]  Варламов, как вы знаете, мамкин атлант и бизнесмен, который уже давно-давно делегировал секс со своей
# [00:03:16,180 --> 00:03:20,700]  женой, даже другим людям, потому что ну зачем париться, делегирование это наше все, поэтому и
# [00:03:20,700 --> 00:03:25,900]  судили Варламова заочно. Не гонять же великого бизнесмена туда-обратно. Но на самом деле судили
# [00:03:25,900 --> 00:03:30,420]  его заочно, потому что из России он давным-давно убежал и в итоге решение вынесли такое, как
# [00:03:30,420 --> 00:03:36,300]  запрашивал прокурор. 8 лет общего режима и штраф 99 миллионов рублей. Я попробую, конечно, связаться
# [00:03:36,300 --> 00:03:41,980]  с Ильей, чтобы спросить, что он думает по этому поводу и что он намерен делать, потому что предыдущие
# [00:03:41,980 --> 00:03:46,460]  разы он мне отвечал и я вставлю просто его комментарий без каких-либо своих комментариев, но
# [00:03:46,460 --> 00:03:51,860]  сперва скажу свое мнение. Нет никаких материалов дела для того, чтобы я мог как-то по факту сказать,
# [00:03:51,860 --> 00:03:56,900]  за какие конкретно высказывания на ютюбе он был осужден. Но если вы помните мой разбор,
# [00:03:56,900 --> 00:04:02,260]  видеоразбор деятельности Ильи Варламовой еще до того, как его признали инагентом, наговорил этот
# [00:04:02,260 --> 00:04:07,780]  человек, не буду называть его полудурком, все-таки он иногда дает мне комментарии и было бы неуважительно
# [00:04:07,780 --> 00:04:13,020]  так, но считай его человеком не очень умным, который наградил Курю кучу хуйни, одни призывы натовских
# [00:04:13,020 --> 00:04:18,820]  танков выезжать в Россию, чего стоить. Жаль, что солдаты НАТО у нас не приветствуются, потому что если бы
# [00:04:18,820 --> 00:04:25,380]  они оказались на своем БТРе, например, на хуторе Родники в Ростовской области, то как минимум одна
# [00:04:25,380 --> 00:04:30,900]  человеческая жизнь была бы, возможно, спасена. Однако то, что он то ставит плашки, то не ставит
# [00:04:30,900 --> 00:04:36,820]  плашки, это да, всегда это было так и мы это с вами уже давно обсуждали. Но что тут скажешь, за многими
# [00:04:36,820 --> 00:04:42,580]  иностранными агентами теперь РОЙ, огромный РОЙ и маленькая тележка таких вот дел. Недавно, например,
# [00:04:42,580 --> 00:04:47,420]  того же слоняру Дудя, который для российской пропаганды сейчас делает больше, чем Симоньян, это я
# [00:04:47,420 --> 00:04:52,900]  вам как работник РТ говорю, но простите, Маргарита, все-таки Дудь это слоняра, который разъебывает
# [00:04:52,900 --> 00:04:57,860]  либералов так, как российская пропаганда никогда не могла. Ну и в общем, Дудя, даже Дудя осудили,
# [00:04:57,860 --> 00:05:02,860]  конечно, очень жаль, не получит он медаль Героя России, хотя для России, я повторюсь, он сейчас
# [00:05:02,860 --> 00:05:07,700]  сделает очень многое с точки зрения ведения медийных войн, хотя я не представляю, кто в принципе к
# [00:05:07,700 --> 00:05:12,180]  Дудю согласится после интервью Макфола и после интервью Невзорова, после интервью Волкова,
# [00:05:12,180 --> 00:05:17,340]  после интервью Певчих, после любого другого десятка интервью, на которых он камня на камня
# [00:05:17,340 --> 00:05:22,740]  от всей либеральной идеологемы не оставил, кто в принципе согласится к этому самому Дудю теперь
# [00:05:22,740 --> 00:05:30,380]  идти. Но осудили бедного Юрку, осудили, хотя конченный дегенерат и учитывая, что осуждены они были
# [00:05:30,380 --> 00:05:35,540]  во время войны, я бы также предусмотрел законодательства по статьям об анагенстве и фейкам возможность
# [00:05:35,540 --> 00:05:40,260]  выйти на мировую с государством, компенсируя причиненный ему ущерб. Этот механизм, наверное,
# [00:05:40,260 --> 00:05:45,180]  можно было бы запустить уже после войны, но только для тех, кто хотел бы свою жизнь связать с Россией,
# [00:05:45,180 --> 00:05:51,420]  кто осознал свою ошибку, потому что должны платить и каяться. С другой стороны, наверное, есть уже,
# [00:05:51,420 --> 00:05:55,940]  я не буду там рассказывать некоторые инсайды конкретные, но есть ребята, которые занимали
# [00:05:55,940 --> 00:06:01,540]  жестко антироссийскую позицию, а потом попытались вернуться в Россию, им сказали, что нашему царю
# [00:06:01,540 --> 00:06:08,660]  императору, богу императора Дюны, императору из Вархаммера, чьей марш хоруса, чья ересь хоруса
# [00:06:08,660 --> 00:06:12,900]  была им пресечена, все-таки сказали присягнуть на верность, ну совсем уж, да, то есть у меня,
# [00:06:12,900 --> 00:06:17,500]  поскольку я был изначально за Россию, я не обязан Владимиру Владимировичу там нализывать и ходить
# [00:06:17,500 --> 00:06:22,620]  рассказывать, что он самый прекрасный царь там на планете Земля. А вот если ты с антироссийской
# [00:06:22,620 --> 00:06:27,420]  позиции изначально зашел, то для того, чтобы как-то исправиться, ну тебе, скорее всего, придется это
# [00:06:27,420 --> 00:06:31,860]  делать и придется в окончательного путяноида превратиться, и ты сам будешь уже бояться хоть
# [00:06:31,860 --> 00:06:36,780]  какую-то критику в сторону действующей власти, ну, называть. Слава богу, меня такая участь миновала.
# [00:06:36,780 --> 00:06:42,500]  В любом случае, я думаю, что такая опция должна появиться, но она должна быть доступна не для
# [00:06:42,500 --> 00:06:47,820]  всех. Все-таки донаты в СУ, это водораздел, это измена и предательство. Я считаю, мы должны,
# [00:06:47,820 --> 00:06:52,620]  подобно тому, как мудрецы-мудрецы зерна от плевел отделяют, мы должны с вами уметь отделять
# [00:06:52,620 --> 00:06:57,460]  настоящего предателя от просто заблудшего человека, потому что на пропаганду велись очень многие,
# [00:06:57,460 --> 00:07:03,100]  когда-то и я там поддерживал Навального и читал Ayn Rand и много чего другого было, поэтому все
# [00:07:03,100 --> 00:07:08,100]  имеют право на ошибку, но все-таки есть водораздел. Конкретно поддержка в СУ, я считаю, этим
# [00:07:08,100 --> 00:07:18,210]  водоразделом является. Если отдаешь кучу денег другой стране, то экономить приходится на себе,
# [00:07:18,410 --> 00:07:24,090]  но мы же знаем, что страны Евросоюза, они готовы жопу порвать ради Украины, поэтому некоторые из
# [00:07:24,090 --> 00:07:28,570]  них прибегают к необычным решениям, ну конечно же для того, чтобы сэкономить. Вот, например,
# [00:07:28,570 --> 00:07:34,490]  Франция решила избавиться от парочки государственных праздников, а именно понедельник после Пасхи и День
# [00:07:34,490 --> 00:07:39,410]  Победы над нацизмом во Второй мировой войне, хотя последнее вполне уместно, учитывая, что а,
# [00:07:39,410 --> 00:07:45,450]  нацизм победили мы, б, они нацизм вернули под новым названием. В общем, они собираются сделать эти
# [00:07:45,450 --> 00:07:52,010]  дни рабочими и таким образом общий КПД страны повысится и они сэкономят целых 4,2 миллиарда. Ну,
# [00:07:52,010 --> 00:07:56,570]  если они идут на такие серьезные ухищрения ради четырех миллиардов евро, то, наверное,
# [00:07:56,570 --> 00:08:02,170]  взять такую астрономическую сумму получается, логически, больше ниоткуда, что, конечно, печально,
# [00:08:02,170 --> 00:08:07,970]  печально для Франции. И тут следите за руками, сперва они улицу Сталинград, названную так в честь
# [00:08:07,970 --> 00:08:12,690]  Великой Победы, которая стала, можно сказать, переломным событием Второй мировой войны,
# [00:08:12,690 --> 00:08:17,290]  переменовывают. Потом они отказываются праздновать победу над нацизмом. Знаете,
# [00:08:17,290 --> 00:08:21,770]  у меня такое ощущение, что экономика это, конечно, базис, с Карлом Марксом спорить
# [00:08:21,770 --> 00:08:26,250]  будет только конченный дебил, например, есть, конечно, один. Ну и, конечно же,
# [00:08:26,250 --> 00:08:31,890]  обращаясь к современным социалистам, я хотел бы посоветовать не уповать на сочинение столетней
# [00:08:31,890 --> 00:08:37,890]  давности, как на Библию. Все-таки экономика, бабки, ресурсы — это база. Но иногда дело не только в
# [00:08:37,890 --> 00:08:44,790]  деньгах. По-моему, Франция собирается, ну, пытается дипломатически подлезать Украине. Типа «все нормально,
# [00:08:44,790 --> 00:08:49,890]  нацисты?» Да нацистов, конечно, в Украине нет, но если бы даже и были, то мы против нацистов ничего
# [00:08:49,890 --> 00:08:55,290]  такого не имеем. Я шучу, конечно, однако в каждой шутке есть доля шутки. Польша, кстати, так не
# [00:08:55,290 --> 00:09:00,810]  делает. Польше почему-то не понравилось, что на концерте Макса Коржа на национальном стадионе в
# [00:09:00,810 --> 00:09:06,530]  Варшаве развернули флаг ОУН УПА — запрещенная террористическая организация. А помимо этого там
# [00:09:06,530 --> 00:09:11,810]  также зажигали фаеры, пытались пробраться в фан-зону без разрешения, и в итоге Польша в лице
# [00:09:11,810 --> 00:09:17,930]  Тузка решила депортировать 63 ухилианты из Украины и Белоруссии обратно к себе домой. Кто-то из них
# [00:09:17,930 --> 00:09:23,330]  начал извиняться, лишь бы не ехать обратно на родину. И тут в дело вмешался посол Украины в
# [00:09:23,330 --> 00:09:29,770]  Польше. Судя по всему, тоже чел, ну, не очень умный. Я не понимаю, зачем украинцы вообще на этот
# [00:09:29,770 --> 00:09:34,810]  стадион пошли. Концерт были на русском языке, и те, кто говорят на этом языке, сейчас убивают
# [00:09:34,810 --> 00:09:40,250]  украинцев, ведут войну и уничтожают Украину. Такое может высовывать только реально тупой
# [00:09:40,250 --> 00:09:48,770]  человек. Зеленский, да, относится к этому числу. И поэтому я не уважаю ни руководителя или директора
# [00:09:48,770 --> 00:09:54,410]  сегодняшней России, ни этот народ. Ну вот и посол Украины в Польше не в курсе, что Украина,
# [00:09:54,410 --> 00:10:00,570]  по большей части, тоже по-прежнему русскоязычная. И сам этот чел, я его, конечно, не знаю, но я руку
# [00:10:00,570 --> 00:10:06,850]  готов отдать на отсечение левую, что он говорит в быту только на русском языке. А еще он может
# [00:10:06,850 --> 00:10:11,490]  посмотреть на то, что стало с Фарион, которую свои же и замочили из-за того, что она разжигала
# [00:10:11,490 --> 00:10:16,970]  ненависть. А еще, знаете, наверное, этот посол мог бы спросить у Азова за русский язык. Я уверен,
# [00:10:16,970 --> 00:10:24,290]  что они ему ответят, обязательно ответят, да так что нахуеет. Причем на русском поймет их без
# [00:10:24,290 --> 00:10:28,610]  переводчика 100 процентов. Президент Навродский тоже высказался по этой теме и сказал, что
# [00:10:28,610 --> 00:10:33,890]  украинское образование не трактует бандеровцев в соответствии с историческими исследованиями.
# [00:10:33,890 --> 00:10:39,570]  А они, на секундочку, я напоминаю бандеровцы, все бандеровцы были и есть убийцы и дегенераты. Но
# [00:10:39,570 --> 00:10:44,250]  если говорить о бандеровцах прошлого, то это дегенераты, ответственные за гибель 120 тысяч
# [00:10:44,250 --> 00:10:49,210]  соотечественников, именно Навродского. И, кстати, забавно, я увидел у Дудя пост на тему того,
# [00:10:49,210 --> 00:10:54,450]  что Корж собрал большой стадион. И Юра там процитировал самого умного человека, по его
# [00:10:54,450 --> 00:10:59,730]  мнению, себя же, по поводу того, что старые пердуны, оказывается, хотят вернуть плохой союз через
# [00:10:59,730 --> 00:11:05,730]  таможенный союз, через КХЛ, а вот настоящие гении типа Юрия Дудя предпочтут союз под
# [00:11:05,730 --> 00:11:11,490]  предводительством Макса Коржа, потому что у него песни неплохие и он выбирает жить в кайф. Ну,
# [00:11:11,490 --> 00:11:17,250]  во-первых, мне интересно было бы узнать, а совок это только таможенный союз и чем таможенный союз
# [00:11:17,250 --> 00:11:23,050]  отличается от евроинтеграции, за исключением более хороших условий? Чем хорош, тогда вместо совка
# [00:11:23,050 --> 00:11:28,930]  евросовок, который нарушает абсолютно любые правила ради одного, лишь бы поставить свою власть в
# [00:11:28,930 --> 00:11:35,290]  странах, ну типа Молдовы и Румынии и прочее. Но, наверное, для Дудя это неплохо. Во-вторых,
# [00:11:35,290 --> 00:11:40,650]  а после цитаты про русскоязычных, почему ты не процитировал посла твоей страны в Польше? Ты же
# [00:11:40,650 --> 00:11:46,690]  украинец? Я украинец. Так что ты украинец думаешь насчет русского языка и отношения к нему со стороны
# [00:11:46,690 --> 00:11:52,290]  представителей твоей страны, Юрка? Но еще вдобавок допуская, что Корж в твоей системе ценности это тот
# [00:11:52,290 --> 00:11:57,770]  самый союз, который ты хотел бы видеть. Наверное, в этой же самой системе порассуждаю о том, кто этот
# [00:11:57,770 --> 00:12:07,600]  союз и с какой стороны решил обосрать. Получается хохлы испортили даже союз Коржей Нерушимых? Но нет,
# [00:12:07,600 --> 00:12:12,680]  Юрка, он же, как и смерть девочки в Белгороде, будет до поры до времени игнорировать, упоминая
# [00:12:12,680 --> 00:12:17,040]  только в контексте того, что он пацифист. Ведь жизнь маленького ребенка для Юрки это лишь
# [00:12:17,040 --> 00:12:21,360]  возможность показать, что он на самом деле хороший. Он не выбирает ни российскую сторону,
# [00:12:21,360 --> 00:12:27,280]  ни европейскую. Он является единственным слоном, который вообще против всех. И при этом тот же самый Юра Дудь,
# [00:12:27,280 --> 00:12:33,640]  который вменял Невзорову в вину следующее. Вы не обсуждаете внутреннюю политику Украины, но я гражданин
# [00:12:33,640 --> 00:12:41,320]  страны, но не обсуждаю проблемы страны. Разве это не тот же подход отрешенности, за которую вы критикуете
# [00:12:41,320 --> 00:12:47,160]  людей в России? И вот этот самый Юра Дудь, который разъебал на этой теме Невзорова, упорно в своем
# [00:12:47,160 --> 00:12:52,760]  посте про концерт Макса Коржа, игнорирует тему украинских нациков, которые этот концерт превратили
# [00:12:52,760 --> 00:12:58,640]  в ебаное шепето. Несмотря на то, что эта ситуация шатает твою хорошую версию Союза, то есть хохлы
# [00:12:58,640 --> 00:13:03,600]  тебе, блять, расшатали версию Союза, но ты не можешь ничего сказать, потому что ты, Юра, на самом деле
# [00:13:03,600 --> 00:13:09,080]  такой же, как Невзоров. Честнее, добрее, умнее, не побоюсь этого слова, потому что не сипишь
# [00:13:09,080 --> 00:13:13,800]  терминологии, в которой не разбираешься направо и налево. Но, тем не менее, Юра, вот эти твои слова...
# [00:13:13,800 --> 00:13:19,080]  Ну, я не моральный коммертон и не хотел бы им никак в жизни быть. Пиздёшь, потому что ты
# [00:13:19,080 --> 00:13:23,880]  пытаешься быть моральным коммертоном, а сам по факту не лучше. Ты точно так же, как российская
# [00:13:23,880 --> 00:13:29,120]  пропаганда, которую ты в этом обвинял десятилетиями, умалчиваешь факты. Ты умалчиваешь об этих проклянных
# [00:13:29,120 --> 00:13:34,600]  нациках на концерте, потому что ты такой же, как Невзоров. Тебе нельзя критиковать Украину, ведь на
# [00:13:34,600 --> 00:13:40,720]  их страну насрали. Ой, извините, напали. Поэтому, раз на Украину напали, можно оправдывать любое
# [00:13:40,720 --> 00:13:46,200]  лицемерие. В том числе и с твоей стороны. Поэтому я, Юра, магнитофон войны, как ты меня и называл.
# [00:13:46,200 --> 00:13:51,440]  Магнитофон войны. А вот посол твоей страны в Польше, ну, ты про него ничего не знаешь, не слышал или
# [00:13:51,440 --> 00:13:56,440]  предпочел не слышать и не высказываться. Да и про нацихов, которые твой прекрасный союз, основанный
# [00:13:56,440 --> 00:14:01,040]  на музыке, доброте и всем хорошим обосрали, ты тоже высказываться не будешь, Юра, потому что ты
# [00:14:01,040 --> 00:14:07,880]  такой же ссыкло, как и Невзорыч. И по факту ты выбрал сторону, хотя твой детский инфантилизм не
# [00:14:07,880 --> 00:14:13,280]  позволяет тебе выбрать ее окончательно. Люди, которые сидят на двух стульях, ну что ж, как говорил
# [00:14:13,280 --> 00:14:19,660]  великий классик, вас будут ебать в образовавшуюся между этими стульями щель. Международная федерация
# [00:14:19,660 --> 00:14:24,900]  волейбола аннулировала результаты вьетнамской сборной. Ну, потому что могут. Все из-за проваленного
# [00:14:24,900 --> 00:14:29,980]  гендерного теста у спортсменок. Да, посмотрите вот на эту фотографию и угадайте, про кого конкретно
# [00:14:29,980 --> 00:14:35,660]  идет речь. Я думаю, Ребус этот несложный, поэтому, наверное, даже не буду подчеркивать, кто есть кто.
# [00:14:35,660 --> 00:14:40,740]  Но интересно получается, конечно. Я-то думал, что Международный Олимпийский комитет сделала
# [00:14:40,740 --> 00:14:45,180]  пиздюльвание девочек мужиками абсолютно нормальной праздникой. Я уже даже собирался выступить,
# [00:14:45,180 --> 00:14:49,940]  уже операция была заказана. А теперь какая-то гребаная федерация волейбола позволила себе
# [00:14:49,940 --> 00:14:55,100]  усомниться в том, что девушки это девушки. Да, гендерная свобода. Как же ты далека от нас.
# [00:14:55,100 --> 00:15:02,060]  Нам срочно нужен Бах. Вот Бах решает такие вопросы. Я бы еще вместо команды волейболистов поставил бы
# [00:15:02,060 --> 00:15:07,700]  команду украинских волейболистов, чтобы можно было на площадке испражняться, избивать женщин,
# [00:15:07,700 --> 00:15:11,420]  просто мужиков по реках, даже не надо никаких операций делать. В любом случае,
# [00:15:11,420 --> 00:15:15,180]  если это будет Украина, Бах подарит ей квалификацию, ведь на нее напали.
# [00:15:15,180 --> 00:15:21,090]  Блять, люди ходят уже на меня посмотреть. В Татарстане задержали диверсантов,
# [00:15:21,090 --> 00:15:25,730]  запускавших беспилотники. Оказалось, что беспилотники российские, а диверсанты
# [00:15:25,730 --> 00:15:31,690]  это курсанты военного училища. Это просто позор. На них обратили внимание местные жители и решили,
# [00:15:31,690 --> 00:15:36,930]  что действовать надо на опережение. Этим гражданам большой поклон и большое спасибо за то,
# [00:15:36,930 --> 00:15:40,490]  что они оказались такими бдительными. Побольше бы таких людей. Но вопрос,
# [00:15:40,490 --> 00:15:45,690]  почему тогда курсантов в итоге задержали? Наверное, место запуска не было согласовано,
# [00:15:45,690 --> 00:15:50,370]  или задержали на всякий случай до дальнейшего выяснения обстоятельств, потому что я все-таки
# [00:15:50,370 --> 00:15:55,050]  специалистом в этом вопросе не являюсь, но в любом случае хорошо, что все хорошо закончилось.
# [00:15:55,050 --> 00:16:01,460]  Ну что ж, это тема, которую я не могу пропустить. Новая волна новостей по поводу блокировок,
# [00:16:01,460 --> 00:16:06,460]  телеги и ватсапа. Первоисточником новости на этот раз снова стала Анастасия Кашиварова,
# [00:16:06,460 --> 00:16:12,140]  которая рассказала о начале блокировки звонков в телеграме и ватсапе. Хотя мы-то с вами уже
# [00:16:12,140 --> 00:16:18,380]  давным-давно догадались, что что-то неправильно, говорили об этом раньше, и тогда прогноз Кашиварова,
# [00:16:18,380 --> 00:16:23,220]  который она до этого давала, не оправдался, и ее официально опровергли. И в этот раз,
# [00:16:23,220 --> 00:16:28,300]  как будто бы все должно было произойти похожим образом. Сперва пошло опровержение из Госдумы,
# [00:16:28,300 --> 00:16:34,220]  мол, никто не собирается блокировать ватсап, это все полная хуйня, но при этом там же подтвердили
# [00:16:34,220 --> 00:16:38,940]  утверждение Кашиваровой, что операторы большой четверки выразили потребность в дополнительных
# [00:16:38,940 --> 00:16:44,140]  доходах, которые они должны получить за счет увеличения обычных звонков, не через мессенджеры.
# [00:16:44,140 --> 00:16:49,340]  И тут 12 августа сообщательно написало, что решение о звонках на самом деле уже принято,
# [00:16:49,340 --> 00:16:55,380]  и 13 августа РКН официально заявил, что звонки в телеграме и ватсапе частично ограничены. Судя
# [00:16:55,380 --> 00:17:00,820]  по всему, это смогли сделать благодаря отслеживанию и блокировке подписи и пометок голосового
# [00:17:00,820 --> 00:17:06,500]  трафика. В министерстве цифры при этом рассказали, что решение РКН сможет положительно повлиять на
# [00:17:06,500 --> 00:17:11,100]  снижение количества мошеннических звонков. А в том случае, если мессенджеры пойдут на
# [00:17:11,100 --> 00:17:16,740]  исполнение законов, то все ограничения будут сняты. Ватсап блокировку звонков уже прокомментировал.
# [00:17:16,740 --> 00:17:22,180]  Оказывается, запрещенная экстремистская мета использует сквозное шифрование, и поэтому российские
# [00:17:22,180 --> 00:17:27,860]  власти эту помойку и блокируют. Ага, ватсап тот самый безопасный мессенджер. Дырявый,
# [00:17:27,860 --> 00:17:32,660]  как Леха Панин, выдающий информацию абсолютно любому по первому требованию. Дуров, кстати,
# [00:17:32,660 --> 00:17:38,300]  эту ситуацию пока никак не прокомментировал, и это очень странно. Обычно он был прям-таки очень
# [00:17:38,300 --> 00:17:42,700]  горазно подобного рода высказывания в случае абсолютно любого ограничения со стороны России.
# [00:17:42,700 --> 00:17:47,380]  Но еще до официальной блокировки Дуров уже анонсировал удаление мошеннических каналов,
# [00:17:47,380 --> 00:17:52,140]  которые как раз таки и специализируются на зарабатывание денег за удаление информации.
# [00:17:52,140 --> 00:17:57,780]  Ну типа как тот канал, который специализировался на том, чтобы нагревать на бабки всяких бизнесменов
# [00:17:57,780 --> 00:18:02,900]  и продавать блок на негатив. Впоминаем историю с бизнесменом Чемизова. И казалось бы, причем тут
# [00:18:02,900 --> 00:18:08,020]  Ксения Собчак. Удален был канал Black Mirror, который сливал переписки российских чиновников и
# [00:18:08,020 --> 00:18:13,980]  бизнесменов и предлагал удалять эти переписки за деньги. И получается, что со стороны Дурова это
# [00:18:13,980 --> 00:18:18,660]  шаг в сторону дружбы Телеграма с российским государством. Но все эти каналы удаляются не
# [00:18:18,660 --> 00:18:23,580]  только в России, при этом остается очень много вопросов относительно блокировки звонков со
# [00:18:23,580 --> 00:18:29,420]  стороны государства. Во-первых, альтернативы. Ну конечно же Мессенджер Макс, который ловит даже
# [00:18:29,420 --> 00:18:34,260]  на Аляске. Но я там канал все-таки завел, меня пригласили в числе первых. Можете подписаться.
# [00:18:34,260 --> 00:18:40,260]  Но вконтакте вы меня знаете, я не буду лизать вам теперь жопы, я все равно буду шутить над этим,
# [00:18:40,260 --> 00:18:45,580]  и мне кажется, что да. Все-таки мошенничество в Максе недавно удалили. Он еще толком не заработал,
# [00:18:45,580 --> 00:18:49,820]  а уже удалили несколько десятков тысяч мошеннических каналов. Поэтому я предполагаю,
# [00:18:49,820 --> 00:18:54,100]  что Телеграм блокировать никто не будет до тех пор, пока Павел Дуров идет на поводу российской
# [00:18:54,100 --> 00:18:58,900]  власти. Ну даже я как-то уничижительно сказал, зачем я это сделал. Идет на поводу. Пока Дуров
# [00:18:58,900 --> 00:19:04,500]  исполняет российские законы, блокировать его никто не будет. Что же касается Макса, то МВД сами
# [00:19:04,500 --> 00:19:10,340]  говорят о том, что там есть случаи обмана девушки из Курской области, и там много каналов блокируется.
# [00:19:10,340 --> 00:19:14,140]  Причем в мессенджеры в прошлом месяце было заблокировано, как я и говорил,
# [00:19:14,140 --> 00:19:19,700]  10 тысяч номеров мошенников. А еще обратите внимание на то, что по отчету Центробанка мошенничество
# [00:19:19,700 --> 00:19:25,700]  через мессенджеры составило охренеть 15 процентов от всех случаев. Тогда как через обычные звонки
# [00:19:25,700 --> 00:19:30,780]  и смс в три раза больше. Через звонки обманывают в три раза больше. Они такие, ну чтобы защитить
# [00:19:31,060 --> 00:19:35,100]  вас от обмана через мессенджеры, мы такие, ну давайте как бы мы вам дадим возможность,
# [00:19:35,100 --> 00:19:40,380]  чтобы вас наебали по телефонам еще больше. Это не говоря о том, что мошенникам в принципе звонить
# [00:19:40,380 --> 00:19:44,740]  не обязательно. Можно либо позвонить с мобильного, а сообщение присылать через мессенджеры,
# [00:19:44,740 --> 00:19:49,300]  либо каким-то другим способом воспользоваться. Так что при любом раскладе, как бы там не было
# [00:19:49,300 --> 00:19:54,620]  все на самом деле, мотивация блокировки звучит абсолютно нахрен неубедительно. Во всяком случае,
# [00:19:54,620 --> 00:19:58,540]  если речь только о мошенниках, а не о продвижении мессенджеры Макса своими
# [00:19:58,540 --> 00:20:03,380]  протекционистскими способами. Однако, вы меня знаете, я люблю объемно все это рассматривать,
# [00:20:03,380 --> 00:20:07,780]  мне кажется тут совокупность факторов. Во-первых, операторы, которые хотят подзаработать,
# [00:20:07,780 --> 00:20:12,700]  и здесь я должен кое-что сказать. Это абсолютно омерзительно, потому что платить теперь у
# [00:20:12,700 --> 00:20:16,820]  операторов, да, они говорят, у нас изнашивается оборудование, нам вот это вот неприбыльно,
# [00:20:16,820 --> 00:20:22,060]  мы теряем деньги, нам надо закупать то, закупать это. И понимаете, они говорят, русский, ты пользуешься
# [00:20:22,060 --> 00:20:27,700]  нашими услугами, заплати за наши издержки. Но, сука, когда были сытые десятые года и вы ловили
# [00:20:27,700 --> 00:20:31,540]  сверхприбыли, вы же с нами не делились. А теперь, когда у вас проблема, может быть,
# [00:20:31,540 --> 00:20:36,460]  тогда национализировать и сделать из трех операторов связи одного единого, который и ловить везде
# [00:20:36,460 --> 00:20:42,180]  будет охуенно. И при этом будет стоимость услуги изначально установлена, и оборудование, ну да,
# [00:20:42,180 --> 00:20:46,380]  мы будем оплачивать с наших законов. Вот только сейчас вы поднимете стоимость звонков и всего
# [00:20:46,380 --> 00:20:51,780]  остального, мы за это заплатим российские граждане, а вы потом такие, о, снова пошли сверхприбыли,
# [00:20:51,780 --> 00:20:56,860]  отмечаем на яхтах, покупаем себе частные суперджеты, летаем на Мальдивы, Каны там,
# [00:20:56,860 --> 00:21:01,940]  и всякие другие кипрские острова. Но какого хуя, блядь, вы долбоебы, десятилетия, не вкладывались
# [00:21:01,940 --> 00:21:06,300]  в собственную инфраструктуру. И теперь, когда пришло время платить по долгам, мы должны за это
# [00:21:06,300 --> 00:21:10,700]  заплатить. Почему, когда какой-нибудь молодой блогер, который случайно добился успеха,
# [00:21:10,700 --> 00:21:15,460]  зарабатывает миллионы, тратит эти деньги на пабрикушки и не покупает даже никакой недвижки,
# [00:21:15,460 --> 00:21:19,860]  а потом теряет популярность свою однодневную, потому что был всего лишь поющими трусами,
# [00:21:19,860 --> 00:21:24,020]  все проебывает, мы не бежим все сразу же скидываться ему на хату, потому что, видите ли,
# [00:21:24,020 --> 00:21:28,260]  ему надо. Но при этом мы то же самое делаем в отношении операторов связи. Ну вы пидарасы,
# [00:21:28,260 --> 00:21:32,980]  че я еще могу сказать. Это первый момент, это мое мнение касательно этой ситуации. Второй момент,
# [00:21:32,980 --> 00:21:38,100]  властям будет намного проще отслеживать звонки и иметь доступ к звонкам через мобильную сеть или
# [00:21:38,100 --> 00:21:44,020]  свой мессенджер. Ну и, конечно же, третий пункт это лоббизм в плане отечественных замен иностранных
# [00:21:44,020 --> 00:21:49,100]  платформ. И опять же, ну да, это хуево, мы как пользователи с вами страдаем, но это ответные
# [00:21:49,100 --> 00:21:53,860]  меры на блокировки всех, кого только можно. Я же вам недавно рассказывал, что вот даже Панченко
# [00:21:53,860 --> 00:21:58,820]  заблокировали огромное количество других каналов на YouTube, и поэтому российская власть вынуждена
# [00:21:58,820 --> 00:22:04,060]  как-то отвечать, потому что ее пытаются заткнуть. И поверьте, если бы был плюрализм мнений, если бы
# [00:22:04,060 --> 00:22:09,060]  российская пропаганда могла бы на YouTube, в TikTok и в остальных социальных сетях себя просто
# [00:22:09,060 --> 00:22:14,620]  противопоставлять пропаганде американской и европейско-либерально-российской, да,
# [00:22:14,620 --> 00:22:18,940]  той самой либерально-российской оппозицией, то все было бы нормально, никто бы ничего не блокировал,
# [00:22:18,940 --> 00:22:23,800]  но тут выхода не остается, тебя затыкают, и ты не можешь позволить тому, чтобы твоих граждан
# [00:22:23,800 --> 00:22:28,820]  зомбировали. У нас и так, блядь, одна либера снята у порога, посмотрите на просмотры Максима Катца,
# [00:22:28,820 --> 00:22:34,500]  но это же пиздец, я в человечество перестаю верить. Но возмущение людей в комментариях относительно
# [00:22:34,500 --> 00:22:40,460]  всех этих блокировок я поддерживаю, потому что звонки это вещь необходима абсолютно всем,
# [00:22:40,460 --> 00:22:46,220]  и звонить по мобилке для большинства людей, я в их числе, это каменный век, поэтому возвращаться
# [00:22:46,220 --> 00:22:50,820]  к этим дегенеративным установкам не стоит. Тем более, что если говорить в масштабах страны,
# [00:22:50,820 --> 00:22:55,640]  то это не про развитие, и в Госдуме некоторые уже просят отказаться от этой идеи и вернуть
# [00:22:55,640 --> 00:23:04,580]  все на место, но насколько эти голоса будут услышаны, конечно же, неизвестно. В Госдуму
# [00:23:04,580 --> 00:23:10,660]  внесли законопроект о маскировке мата, и это еще одна просто охуенная инициатива, а я думал,
# [00:23:10,660 --> 00:23:15,220]  где работают все эти люди, которые пишут мне комментарии на Рутубе о том, что я достал материться,
# [00:23:15,220 --> 00:23:19,940]  а оказывается через одного депутата, Валентина депутата, ну либо у них очень хорошие связи с
# [00:23:19,940 --> 00:23:25,020]  депутатами. В общем, контент, который содержит мат, в общем, там где какой-то долбоеб сидит и
# [00:23:25,020 --> 00:23:30,140]  много матерится, предлагается блокировать. Ох уж эти чувствительные натуры, повсюду умирают люди,
# [00:23:30,140 --> 00:23:34,580]  а им лишь бы мат запретить. И, честно говоря, я думаю, это хорошая инициатива для того,
# [00:23:34,580 --> 00:23:40,340]  чтобы все русскоязычное пространство интернета вообще осталось без контента. Ведь зачем вам чел,
# [00:23:40,340 --> 00:23:46,180]  который матерится, противостоя при этом угрозе запада, кибер-угрозе запада, разоблачает ложь,
# [00:23:46,180 --> 00:23:50,540]  делая это в популярном молодежном формате на том языке, на котором ему культурно и интересно
# [00:23:50,540 --> 00:23:54,740]  разговаривать. Вместо этого давайте посадим биороботов с позитивной лыбой комсомольца,
# [00:23:54,740 --> 00:24:00,500]  которые будут заученным текстом от Федерального агентства, Центрового назначения, субъекта
# [00:24:00,500 --> 00:24:06,180]  Российской Федерации, опровергаю ложь данного индивида. Вот эта хуйня, блядь, действительно
# [00:24:06,180 --> 00:24:11,180]  будет работать. А потом ваши дети будут ходить в банкоматы подрывать, блядь, военкоматы и релейные
# [00:24:11,180 --> 00:24:15,700]  шкафы, просто потому что им на нормальном языке никто не объяснил, что все либералы пидорасы,
# [00:24:15,700 --> 00:24:20,740]  а либеральные идеи... Это подзалубная тварь. Ну, в целом, если закон примут, ну, конечно,
# [00:24:20,740 --> 00:24:26,060]  я его буду соблюдать. И единственное, на сасфриксе только платный контент будет без запиканного
# [00:24:26,060 --> 00:24:31,820]  мата. У меня нет выбора, я считаю этот закон дебильным, считаю его вредоносным, считаю его
# [00:24:31,820 --> 00:24:37,100]  губительным для контента, потому что, ну, без мата контента практически не будет. Но, если власть
# [00:24:37,100 --> 00:24:41,700]  имущие так сделают, ну, мне остается закон только соблюдать, потому что, каким бы ни был глупым
# [00:24:41,700 --> 00:24:46,420]  закон, я буду против него выступать, но соблюдать буду обязан, потому что, ну, на воле заебись,
# [00:24:46,420 --> 00:24:51,620]  ребят. Кто бы что ни говорил, там фарту масти ауе, но на воле заебись, я знаю. В тюрьме не был,
# [00:24:51,620 --> 00:24:58,400]  но сравнить не хочу. Договорничок шагает, по планете радуются взрослые, радуются дети. По крайней
# [00:24:58,400 --> 00:25:04,600]  мере, некоторые всю неделю ждали каких-то позитивных новостей, и то тут, то там появлялись новые инсайды
# [00:25:04,600 --> 00:25:10,160]  относительно каких-то там соглашений, тайных предложений с обеих сторон. В среду Трамп созвонился
# [00:25:10,160 --> 00:25:16,360]  с европартнерами и Зеленским, проведя телеконференцию. На этой конференции Уитков сказал, Путин готов
# [00:25:16,360 --> 00:25:21,920]  прекратить боевые действия в обмен на уступку некоторых территорий ЛДНР, ну, в границах ЛДНР,
# [00:25:21,920 --> 00:25:26,720]  а еще некоторые участники подумали, что Путин готов уступить Херсонскую и Запорожскую области,
# [00:25:26,720 --> 00:25:31,400]  которые контролируются на данный момент России, что естественно звучит как бред. Путин сказал,
# [00:25:31,400 --> 00:25:36,920]  Украина должна выйти из этих областей. Уитков такой, а, вы готовы выйти из этих областей? Да,
# [00:25:36,920 --> 00:25:41,760]  переговоры. Я объясню, почему это звучит как бред. Я прямо перед этим, перед тем, как прошли
# [00:25:41,760 --> 00:25:46,640]  переговоры, выпустил на сасфиксе ролик с разбором КАЦа, но, по сути, такой же ролик выпустил
# [00:25:46,640 --> 00:25:51,760]  и иностранный агент Штефанов, где обосрался в каждом тезисе. И их ролики с КАЦом, по сути,
# [00:25:51,760 --> 00:25:56,680]  были, ну, продублированы. КАЦ через слово вставлял фразу про воздушный террор,
# [00:25:56,680 --> 00:26:01,840]  пытаясь это вложить в нарратив. Воздушный террор Украины – чистое варварство. И сделал
# [00:26:01,840 --> 00:26:06,560]  абсолютно идиотские предположения, в принципе, как и Штефанов. Из того, что пока можно понять,
# [00:26:06,560 --> 00:26:12,080]  звучит все примерно так. Россия выходит из Херсонской и Запорожской области, а в ответ Украина
# [00:26:12,080 --> 00:26:17,680]  выводит войска из Донецка и Луганск. И это абсолютный дебилизм, что Штефанов, что КАЦ абсолютно
# [00:26:17,680 --> 00:26:23,200]  тупые. С чего бы Путину брать просто и отказываться от сухопутного коридора в Крым при продолжающейся
# [00:26:23,200 --> 00:26:28,800]  инициативе российской армии на фронте. То есть мы предложим Украине намного меньше территории,
# [00:26:28,800 --> 00:26:34,200]  чем они хотят. Это факт. Но если они не согласятся на это, то уже через год у нас будет намного больше
# [00:26:34,200 --> 00:26:39,600]  территории. Это та же ситуация, что и в 22-м году. Они тогда не захотели договариваться, думали,
# [00:26:39,600 --> 00:26:43,880]  что они еще Крым себе вернут. В итоге потеряли несколько областей, которые теперь являются
